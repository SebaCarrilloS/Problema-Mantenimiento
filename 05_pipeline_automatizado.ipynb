# %% [markdown]
# # Notebook 05 — Pipeline Automatizado y Orquestación
#
# En este notebook se integra todo el proyecto en un flujo automatizado reproducible:
#
# 1. Carga de datos procesados.
# 2. Carga del modelo entrenado.
# 3. Scoring operativo.
# 4. Optimización de mantención.
# 5. Generación de reportes.
# 6. Exportación de resultados.
#
# Este pipeline es la base para su ejecución mediante `main.py` o tareas programadas.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import joblib
import json
from datetime import datetime

SEED = 42
np.random.seed(SEED)

pd.set_option("display.max_columns", 200)
